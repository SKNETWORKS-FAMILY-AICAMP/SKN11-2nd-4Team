# %%
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
path = os.path.join(os.path.split(os.getcwd())[0], "data\\EDA\\unoversampling_EDA.csv")

prep_data = pd.read_csv(path)
prep_data
# Out:
#         Unnamed: 0  tier  rank    winRate  veteran  freshBlood  hotStreak  \
# 0                0     0     2  22.222222        0           0          0
# 1                1     0     2  22.222222        0           0          0
# 2                2     0     2  22.222222        0           0          0
# 3                3     2     3  57.692308        0           0          0
# 4                4     2     3  57.692308        0           0          0
# ...            ...   ...   ...        ...      ...         ...        ...
# 694170      694170     9     0  27.272727        0           0          0
# 694171      694171     9     0  27.272727        0           0          0
# 694172      694172     8     0  62.222222        0           1          0
# 694173      694173     8     0  62.222222        0           1          0
# 694174      694174     8     0  62.222222        0           1          0
#
#         revisionDate  summonerLevel  championId  championLevel  \
# 0                 41             38          64              5
# 1                 41             38          76              5
# 2                 41             38          92              5
# 3                  3            181          81             20
# 4                  3            181         145             20
# ...              ...            ...         ...            ...
# 694170             5            394          64             21
# 694171             5            394         350             12
# 694172             3            382          80             34
# 694173             3            382          28             29
# 694174             3            382          20             17
#
#         championPoints  lastPlayTime  championSeasonMilestone  churn
# 0                29339            70                        0      1
# 1                28572            70                        0      1
# 2                24741           109                        0      1
# 3               196312            36                        0      0
# 4               190530            20                        1      0
# ...                ...           ...                      ...    ...
# 694170          214339             7                        1      0
# 694171          103144            48                        0      0
# 694172          416320             3                        7      0
# 694173          330003             7                        1      0
# 694174          201140            23                        1      0
#
# [694175 rows x 15 columns]

# %%
df = prep_data.drop(columns=['Unnamed: 0', "tier", "rank", "winRate", "veteran", "hotStreak", "revisionDate", "championId", "championLevel", "championPoints"])
df
# Out:
#         freshBlood  summonerLevel  lastPlayTime  championSeasonMilestone  \
# 0                0             38            70                        0
# 1                0             38            70                        0
# 2                0             38           109                        0
# 3                0            181            36                        0
# 4                0            181            20                        1
# ...            ...            ...           ...                      ...
# 694170           0            394             7                        1
# 694171           0            394            48                        0
# 694172           1            382             3                        7
# 694173           1            382             7                        1
# 694174           1            382            23                        1
#
#         churn
# 0           1
# 1           1
# 2           1
# 3           0
# 4           0
# ...       ...
# 694170      0
# 694171      0
# 694172      0
# 694173      0
# 694174      0
#
# [694175 rows x 5 columns]

# %%
X = df.drop('churn', axis=1)
y = df['churn']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
knn = KNeighborsClassifier()
lr = LogisticRegression()
dt = DecisionTreeClassifier()

model1 = VotingClassifier(
    estimators=[
        ('knn', knn),
        ('lr', lr),
        ('dt', dt)
    ],
    voting='hard'
)

model1.fit(X_train, y_train)

# 예측 및 평가
y_pred_train = model1.predict(X_train)
acc_score_train = accuracy_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)
print("훈련 데이터 평가: ", acc_score_train)
print("훈련 데이터 f1 평가: ", f1_train)

y_pred_test = model1.predict(X_test)
acc_score_test = accuracy_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print("평가 데이터 평가: ", acc_score_test)
print("평가 데이터 f1 평가: ", f1_test)
# Out:
# 훈련 데이터 평가:  0.8956477812500601
# 훈련 데이터 f1 평가:  0.3962974898047626
# 평가 데이터 평가:  0.864288019176693
# 평가 데이터 f1 평가:  0.20939912722390064

# %%
df2 = prep_data.drop(columns=['Unnamed: 0',  "revisionDate", "championId"])
df2
# Out:
#         tier  rank    winRate  veteran  freshBlood  hotStreak  summonerLevel  \
# 0          0     2  22.222222        0           0          0             38
# 1          0     2  22.222222        0           0          0             38
# 2          0     2  22.222222        0           0          0             38
# 3          2     3  57.692308        0           0          0            181
# 4          2     3  57.692308        0           0          0            181
# ...      ...   ...        ...      ...         ...        ...            ...
# 694170     9     0  27.272727        0           0          0            394
# 694171     9     0  27.272727        0           0          0            394
# 694172     8     0  62.222222        0           1          0            382
# 694173     8     0  62.222222        0           1          0            382
# 694174     8     0  62.222222        0           1          0            382
#
#         championLevel  championPoints  lastPlayTime  championSeasonMilestone  \
# 0                   5           29339            70                        0
# 1                   5           28572            70                        0
# 2                   5           24741           109                        0
# 3                  20          196312            36                        0
# 4                  20          190530            20                        1
# ...               ...             ...           ...                      ...
# 694170             21          214339             7                        1
# 694171             12          103144            48                        0
# 694172             34          416320             3                        7
# 694173             29          330003             7                        1
# 694174             17          201140            23                        1
#
#         churn
# 0           1
# 1           1
# 2           1
# 3           0
# 4           0
# ...       ...
# 694170      0
# 694171      0
# 694172      0
# 694173      0
# 694174      0
#
# [694175 rows x 12 columns]

# %%
X = df2.drop('churn', axis=1)
y = df2['churn']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
knn = KNeighborsClassifier()
lr = LogisticRegression(max_iter=300)
dt = DecisionTreeClassifier()

model2 = VotingClassifier(
    estimators=[
        ('knn', knn),
        ('lr', lr),
        ('dt', dt)
    ],
    voting='hard'
)

model2.fit(X_train, y_train)

# 예측 및 평가
y_pred_train = model2.predict(X_train)
acc_score_train = accuracy_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

y_pred_test = model2.predict(X_test)
acc_score_test = accuracy_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print("훈련 데이터 평가: ", acc_score_train)
print("평가 데이터 평가: ", acc_score_test)
print("훈련 데이터 f1 평가: ", f1_train)
print("평가 데이터 f1 평가: ", f1_test)
# Out:
# c:\Users\maest\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 훈련 데이터 평가:  0.9086877270081881
# 평가 데이터 평가:  0.8709088185128844
# 훈련 데이터 f1 평가:  0.4486325995685556
# 평가 데이터 f1 평가:  0.12818616959178114

# %%
from imblearn.over_sampling import SMOTE

# %%
columns = ["churn"] # "veteran", "freshBlood", "churn"
oversampl_X_data = df2.copy()
smote = SMOTE(random_state=42)

for column in columns:
    oversampl_y_data = oversampl_X_data[column]
    oversampl_X_data = oversampl_X_data.drop(labels=column, axis=1)
    
    oversampl_X_data, oversampl_y_data = smote.fit_resample(oversampl_X_data, oversampl_y_data)
    oversampl_X_data = pd.concat([oversampl_X_data, oversampl_y_data], axis=1)

oversampl_data = oversampl_X_data

# %%
oversampl_data
# Out:
#          tier  rank    winRate  veteran  freshBlood  hotStreak  summonerLevel  \
# 0           0     2  22.222222        0           0          0             38
# 1           0     2  22.222222        0           0          0             38
# 2           0     2  22.222222        0           0          0             38
# 3           2     3  57.692308        0           0          0            181
# 4           2     3  57.692308        0           0          0            181
# ...       ...   ...        ...      ...         ...        ...            ...
# 1210461     6     2  51.000725        0           0          0            318
# 1210462     9     1  51.648573        0           0          0             44
# 1210463     4     2  42.771713        0           0          0            447
# 1210464     7     1  32.990912        0           0          0             75
# 1210465     0     3  41.556252        0           0          0             94
#
#          championLevel  championPoints  lastPlayTime  championSeasonMilestone  \
# 0                    5           29339            70                        0
# 1                    5           28572            70                        0
# 2                    5           24741           109                        0
# 3                   20          196312            36                        0
# 4                   20          190530            20                        1
# ...                ...             ...           ...                      ...
# 1210461              8           70284            81                        0
# 1210462              4           15402            73                        0
# 1210463             21          250244            46                        0
# 1210464              5           27283            66                        0
# 1210465              6           32336            47                        0
#
#          churn
# 0            1
# 1            1
# 2            1
# 3            0
# 4            0
# ...        ...
# 1210461      1
# 1210462      1
# 1210463      1
# 1210464      1
# 1210465      1
#
# [1210466 rows x 12 columns]

# %%
X = oversampl_data.drop('churn', axis=1)
y = oversampl_data['churn']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
knn = KNeighborsClassifier()
lr = LogisticRegression(max_iter=300)
dt = DecisionTreeClassifier()

model3 = VotingClassifier(
    estimators=[
        ('knn', knn),
        ('lr', lr),
        ('dt', dt)
    ],
    voting='hard'
)

model3.fit(X_train, y_train)

# 예측 및 평가
y_pred_train = model3.predict(X_train)
acc_score_train = accuracy_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

y_pred_test = model3.predict(X_test)
acc_score_test = accuracy_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print("훈련 데이터 평가: ", acc_score_train)
print("평가 데이터 평가: ", acc_score_test)
print("훈련 데이터 f1 평가: ", f1_train)
print("평가 데이터 f1 평가: ", f1_test)
# Out:
# c:\Users\maest\anaconda3\envs\pystudy_env\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 훈련 데이터 평가:  0.9382683684180959
# 평가 데이터 평가:  0.8533063244959801
# 훈련 데이터 f1 평가:  0.9412269322289678
# 평가 데이터 f1 평가:  0.8628318584070797

# %%
from sklearn.preprocessing import StandardScaler

# sc = StandardScaler()
# X_train_scaled= sc.fit_transform(X_train, y_train)

# model3.fit(X_train_scaled, y_train)

# # 예측 및 평가
# y_pred_train = model3.predict(X_train_scaled)
# acc_score_train = accuracy_score(y_train, y_pred_train)
# f1_train = f1_score(y_train, y_pred_train)

# y_pred_test = model3.predict(X_test)
# acc_score_test = accuracy_score(y_test, y_pred_test)
# f1_test = f1_score(y_test, y_pred_test)
# print("훈련 데이터 평가: ", acc_score_train)
# print("평가 데이터 평가: ", acc_score_test)
# print("훈련 데이터 f1 평가: ", f1_train)
# print("평가 데이터 f1 평가: ", f1_test)

# %%
sc = StandardScaler()
data_scaler = sc.fit_transform(oversampl_data)
data = pd.DataFrame(data_scaler, index=oversampl_data.index, columns=oversampl_data.columns)
data
# Out:
#              tier      rank   winRate   veteran  freshBlood  hotStreak  \
# 0       -1.611034  0.359567 -2.117532 -0.034186   -0.221917   -0.25969
# 1       -1.611034  0.359567 -2.117532 -0.034186   -0.221917   -0.25969
# 2       -1.611034  0.359567 -2.117532 -0.034186   -0.221917   -0.25969
# 3       -0.932916  1.316199  0.699691 -0.034186   -0.221917   -0.25969
# 4       -0.932916  1.316199  0.699691 -0.034186   -0.221917   -0.25969
# ...           ...       ...       ...       ...         ...        ...
# 1210461  0.423319  0.359567  0.168210 -0.034186   -0.221917   -0.25969
# 1210462  1.440496 -0.597064  0.219666 -0.034186   -0.221917   -0.25969
# 1210463 -0.254799  0.359567 -0.485382 -0.034186   -0.221917   -0.25969
# 1210464  0.762378 -0.597064 -1.262225 -0.034186   -0.221917   -0.25969
# 1210465 -1.611034  1.316199 -0.581920 -0.034186   -0.221917   -0.25969
#
#          summonerLevel  championLevel  championPoints  lastPlayTime  \
# 0            -1.102458      -0.548439       -0.575796     -0.234332
# 1            -1.102458      -0.548439       -0.579245     -0.234332
# 2            -1.102458      -0.548439       -0.596471     -0.092775
# 3            -0.220233       0.256140        0.175022     -0.357741
# 4            -0.220233       0.256140        0.149023     -0.415816
# ...                ...            ...             ...           ...
# 1210461       0.624975      -0.387523       -0.391681     -0.194406
# 1210462      -1.065441      -0.602077       -0.638465     -0.223443
# 1210463       1.420829       0.309779        0.417535     -0.321444
# 1210464      -0.874190      -0.548439       -0.585041     -0.248851
# 1210465      -0.756971      -0.494800       -0.562319     -0.317815
#
#          championSeasonMilestone  churn
# 0                      -0.326708    1.0
# 1                      -0.326708    1.0
# 2                      -0.326708    1.0
# 3                      -0.326708   -1.0
# 4                       0.330471   -1.0
# ...                          ...    ...
# 1210461                -0.326708    1.0
# 1210462                -0.326708    1.0
# 1210463                -0.326708    1.0
# 1210464                -0.326708    1.0
# 1210465                -0.326708    1.0
#
# [1210466 rows x 12 columns]

# %%
X = data.drop('churn', axis=1)
y = data['churn']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model3.fit(X_train, y_train)

# 예측 및 평가
y_pred_train = model3.predict(X_train)
acc_score_train = accuracy_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

y_pred_test = model3.predict(X_test)
acc_score_test = accuracy_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)
print("훈련 데이터 평가: ", acc_score_train)
print("평가 데이터 평가: ", acc_score_test)
print("훈련 데이터 f1 평가: ", f1_train)
print("평가 데이터 f1 평가: ", f1_test)
# Out:
# 훈련 데이터 평가:  0.9200472765845421
# 평가 데이터 평가:  0.8385583096785706
# 훈련 데이터 f1 평가:  0.923889644440856
# 평가 데이터 f1 평가:  0.8494039967818601

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (1.2.7)
# Requirement already satisfied: graphviz in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from catboost) (3.10.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from catboost) (6.0.1)
# Requirement already satisfied: six in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib->catboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\maest\anaconda3\envs\pystudy_env\lib\site-packages (from plotly->catboost) (1.32.0)

# %%
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score, f1_score

catboost = CatBoostClassifier(iterations=300, learning_rate=0.05, depth=10, verbose=0) 
rf = RandomForestClassifier(n_estimators=100, random_state=42)  
lgbm = LGBMClassifier(n_estimators=100, learning_rate=0.05, random_state=42) 

model4 = VotingClassifier(
    estimators=[('catboost', catboost), ('rf', rf), ('lgbm', lgbm)],
    voting='hard'
)

model4.fit(X_train, y_train)

y_pred_train = model4.predict(X_train)
acc_score_train = accuracy_score(y_train, y_pred_train)
f1_train = f1_score(y_train, y_pred_train)

y_pred_test = model4.predict(X_test)
acc_score_test = accuracy_score(y_test, y_pred_test)
f1_test = f1_score(y_test, y_pred_test)

print("훈련 데이터 정확도: ", acc_score_train)
print("테스트 데이터 정확도: ", acc_score_test)
print("훈련 데이터 F1 스코어: ", f1_train)
print("테스트 데이터 F1 스코어: ", f1_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from catboost import CatBoostClassifier
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 from lightgbm import LGBMClassifier
#
# File c:\Users\maest\anaconda3\envs\pystudy_env\Lib\site-packages\catboost\__init__.py:1
# ----> 1 from .core import (
#       2     FeaturesData, EFstrType, EShapCalcType, EFeaturesSelectionAlgorithm, EFeaturesSelectionGrouping,
#       3     Pool, CatBoost, CatBoostClassifier, CatBoostRegressor, CatBoostRanker, CatBoostError, cv, sample_gaussian_process, train,
#       4     sum_models, _have_equal_features, to_regressor, to_classifier, to_ranker, MultiRegressionCustomMetric,
#       5     MultiRegressionCustomObjective, MultiTargetCustomMetric, MultiTargetCustomObjective
#       6 )  # noqa
#       7 from .version import VERSION as __version__  # noqa
#       8 __all__ = [
#       9     'FeaturesData', 'EFstrType', 'EShapCalcType', 'EFeaturesSelectionAlgorithm', 'EFeaturesSelectionGrouping',
#      10     'Pool', 'CatBoost', 'CatBoostClassifier', 'CatBoostRegressor', 'CatBoostRanker', 'CatboostError',
#    (...)     13     'MultiTargetCustomMetric', 'MultiTargetCustomObjective'
#      14 ]
#
# File c:\Users\maest\anaconda3\envs\pystudy_env\Lib\site-packages\catboost\core.py:45
#      40         pass
#      42 import scipy.sparse
# ---> 45 from .plot_helpers import save_plot_file, try_plot_offline, OfflineMetricVisualizer
#      46 from . import _catboost
#      47 from .metrics import BuiltinMetric
#
# File c:\Users\maest\anaconda3\envs\pystudy_env\Lib\site-packages\catboost\plot_helpers.py:5
#       2 import os
#       3 import warnings
# ----> 5 from . import _catboost
#       6 fspath = _catboost.fspath
#       9 def try_plot_offline(figs):
#
# File _catboost.pyx:1, in init _catboost()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
